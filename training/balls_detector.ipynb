# %%
from ultralytics import YOLO

# %%
model = YOLO('models/yolo11l.pt', task='detection')

# %%
model.train(
    data='ball_data.yaml',
    batch=8,
    epochs=150,
    freeze=10,
    lrf=0.001
)
# Out:
# Ultralytics 8.3.122 🚀 Python-3.13.2 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# ...
